# %% [markdown]
# Aim: To apply principle Component Analysis For dimentionality reduction and visualize the transformed feature space.
# Name : Vaishnavi G. Sandokar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/ML /Breast_Cancer_dataset.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
x=cancer.data
y=cancer.target

# %%
print(x.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

# %%
print(x_scaled)
# Out:
# [[ 1.09706398 -2.07333501  1.26993369 ...  2.29607613  2.75062224
#    1.93701461]
#  [ 1.82982061 -0.35363241  1.68595471 ...  1.0870843  -0.24388967
#    0.28118999]
#  [ 1.57988811  0.45618695  1.56650313 ...  1.95500035  1.152255
#    0.20139121]
#  ...
#  [ 0.70228425  2.0455738   0.67267578 ...  0.41406869 -1.10454895
#   -0.31840916]
#  [ 1.83834103  2.33645719  1.98252415 ...  2.28998549  1.91908301
#    2.21963528]
#  [-1.80840125  1.22179204 -1.81438851 ... -1.74506282 -0.04813821
#   -0.75120669]]

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

# %%
print("Explained Variance Ratio:",pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.44272026 0.18971182]

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Cancer Dataset")
# Out:
# Text(0.5, 1.0, 'PCA Visualization of  Dataset')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Cancer Dataset")
plt.title("PCA -Cancer Dataset")
plt.colorbar(label="Class")
plt.show()

# %%
pca = PCA()
pca.fit(x_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.show()
