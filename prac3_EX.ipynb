# %%
#PracNo:03 Extra
#Name: Vaishnavi G. Sandokar(CS24D007)
#Aim: To implement Logistic Regression for binary classification problem and analysis the classification performance
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/ML /diabetes_prediction_dataset.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df = df[df['diabetes'] == 1]   # if you want only diabetic patients

# %%
X = df.drop('diabetes', axis=1)
y = df['diabetes']

# %%
df.shape
# Out:
# (8500, 9)

# %%
import seaborn as sns
df = sns.load_dataset('iris')
df = df[df['species'] != 'setosa']
df['species'] = df['species'].map({'versicolor': 0, 'virginica': 1})

# %%
X = df.iloc[:,:-1]
print(X)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 50            7.0          3.2           4.7          1.4
# 51            6.4          3.2           4.5          1.5
# 52            6.9          3.1           4.9          1.5
# 53            5.5          2.3           4.0          1.3
# 54            6.5          2.8           4.6          1.5
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [100 rows x 4 columns]

# %%
y = df['species']
print(y)
# Out:
# 50     0
# 51     0
# 52     0
# 53     0
# 54     0
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: species, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.7,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
parameter={'penalty':['l1','l2','elasticnet', None],'C':[1,2,3,4,5,6,19,20,30,40,50],'l1_ratio':[0.1, 0.5, 0.9],'max_iter':[1000,2000,3000]}

# %%
classifier_regressor=GridSearchCV(classifier,param_grid=parameter,scoring='accuracy',cv=5)

# %%
print(classifier_regressor.best_params_)
# Out:
# {'C': 3, 'l1_ratio': 0.1, 'max_iter': 1000, 'penalty': 'l2'}

# %%
y = df['species']

# Features
X = df.drop('species', axis=1)

# Separate categorical and numerical columns
# For the Iris dataset (versicolor vs virginica), all features are numerical.
categorical_cols = []
numerical_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# Preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        # OneHotEncoder is not needed as there are no categorical columns in the current df
        ('cat', OneHotEncoder(drop='first'), categorical_cols) # This will be skipped if categorical_cols is empty
    ]
)

# %%
y=df['species']
x=df.drop('species',axis=1)
X=df.drop
categorical_

# %%
classifier = LogisticRegression()

# Create pipeline
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', classifier)
])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Parameter grid
parameter = {
    'classifier__penalty': ['l1', 'l2', 'elasticnet', None],
    'classifier__C': [1, 2, 3, 5, 10],
    'classifier__l1_ratio': [0.1, 0.5, 0.9],
    'classifier__max_iter': [1000, 2000]
}

# %%
classifier_regressor = GridSearchCV(
    pipe,
    param_grid=parameter,
    scoring='accuracy',
    cv=5
)

# Train model
classifier_regressor.fit(X_train, y_train)

# Best parameters
print("Best Parameters:", classifier_regressor.best_params_)
print("Best Accuracy:", classifier_regressor.best_score_)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# ...
