# %% [markdown]
# Aim: To apply support vector machine for classification and analyze the impact of different on model accuracy.
# Name: Vaishnavi Sandokar
# USN : CS24D007

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/ML /Student_Performance_dataset_5000.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline  \
# 0                81                  38              1                  0
# 1               111                 339              0                  0
# 2                68                 266              0                  1
# 3               113                 480              1                  1
# 4               121                  24              1                  0
#
#    internet_quality mental_health_score  focus_index  burnout_level  \
# 0              Good                  10        43.05          31.77
# 1              Good                   3        15.92          37.00
# 2              Good                   8        27.39          34.37
# 3              Poor                   3        22.31          77.31
# 4              Good                   8        38.11          39.53
#
#    productivity_score  exam_score
# 0               73.65       50.16
# 1               13.70        1.00
# 2               45.15       18.30
# 3               20.92        9.37
# 4               59.23       27.81
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# 25%                1.320000            1.990000      0.670000     6.237500
# 50%                2.010000            2.980000      1.490000     7.010000
# 75%                2.690000            4.030000      2.340000     7.810000
# max                6.000000            8.280000      5.640000    10.000000
#
#        screen_time_hours  exercise_minutes  caffeine_intake_mg  part_time_job  \
# count        5000.000000       5000.000000         5000.000000    5000.000000
# mean            6.979588         74.535600          251.450400       0.498200
# std             2.486214         42.932293          143.842712       0.500047
# min             1.000000          0.000000            0.000000       0.000000
# 25%             5.280000         37.000000          129.000000       0.000000
# 50%             6.950000         75.000000          252.000000       0.000000
# 75%             8.710000        112.000000          376.000000       1.000000
# max            15.300000        149.000000          499.000000       1.000000
#
#        upcoming_deadline  mental_health_score  focus_index  burnout_level  \
# count        5000.000000          5000.000000  5000.000000    5000.000000
# mean            0.501400             5.507400    29.431616      45.615324
# std             0.500048             2.869145     9.962902      14.246591
# min             0.000000             1.000000     1.000000       1.000000
# 25%             0.000000             3.000000    22.567500      35.727500
# 50%             1.000000             5.000000    29.430000      45.690000
# 75%             1.000000             8.000000    36.242500      55.352500
# max             1.000000            10.000000    63.480000      97.580000
#
#        productivity_score   exam_score
# count         5000.000000  5000.000000
# mean            37.267716    18.803752
# std             16.849397    12.130840
# min              1.000000     1.000000
# 25%             25.290000     9.337500
# 50%             36.860000    18.010000
# 75%             49.142500    27.400000
# max             98.020000    64.090000

# %%
df.shape
# Out:
# (5000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   object
#  3   academic_level        5000 non-null   object
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
#  14  upcoming_deadline     5000 non-null   int64
#  15  internet_quality      5000 non-null   object
#  16  mental_health_score   5000 non-null   int64
#  17  focus_index           5000 non-null   float64
#  18  burnout_level         5000 non-null   float64
#  19  productivity_score    5000 non-null   float64
#  20  exam_score            5000 non-null   float64
# dtypes: float64(11), int64(7), object(3)
# memory usage: 820.4+ KB

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='object')

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [student_id, age, gender, academic_level, study_hours, self_study_hours, online_classes_hours, social_media_hours, gaming_hours, sleep_hours, screen_time_hours, exercise_minutes, caffeine_intake_mg, part_time_job, upcoming_deadline, internet_quality, mental_health_score, focus_index, burnout_level, productivity_score, exam_score]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.shape
# Out:
# (5000, 21)

# %%
before_rows=df.shape[0]
df=df.dropna()
after_rows=df.shape[0]
print('before_rows:',before_rows)
print('after_rows:',after_rows)
print("the number of dropped rows are:", before_rows-after_rows)
# Out:
# before_rows: 5000
# after_rows: 5000
# the number of dropped rows are: 0

# %%
df.shape
# Out:
# (5000, 21)

# %%
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline  \
# 0                81                  38              1                  0
# 1               111                 339              0                  0
# 2                68                 266              0                  1
# 3               113                 480              1                  1
# 4               121                  24              1                  0
#
#    internet_quality mental_health_score  focus_index  burnout_level  \
# 0              Good                  10        43.05          31.77
# 1              Good                   3        15.92          37.00
# 2              Good                   8        27.39          34.37
# 3              Poor                   3        22.31          77.31
# 4              Good                   8        38.11          39.53
#
#    productivity_score  exam_score
# 0               73.65       50.16
# 1               13.70        1.00
# 2               45.15       18.30
# 3               20.92        9.37
# 4               59.23       27.81
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)

# %%
X_train
# Out:
#       age  study_hours  self_study_hours  online_classes_hours  \
# 4227   23         3.72              1.23                  2.59
# 4676   23         6.27              0.78                  1.30
# 800    18         7.23              1.97                  3.13
# 3671   20         2.19              1.61                  1.70
# 4193   17         3.11              4.04                  1.14
# ...   ...          ...               ...                   ...
# 4426   18         4.30              2.34                  0.70
# 466    25         3.85              2.63                  2.30
# 3092   17         6.55              2.90                  3.11
# 3772   21         4.16              0.00                  1.27
# 860    18         3.96              0.98                  1.77
#
#       social_media_hours  gaming_hours  sleep_hours  screen_time_hours  \
# 4227                2.86          1.75         6.69               5.52
# 4676                2.75          0.00         7.12               6.55
# 800                 2.80          2.06         6.18               9.83
# 3671                1.43          1.94         8.77               6.28
# 4193                2.22          0.95         6.61               3.27
# ...                  ...           ...          ...                ...
# 4426                0.43          4.04         7.39               7.81
# 466                 2.55          2.46         8.15               6.81
# 3092                3.42          2.44         6.17               6.08
# 3772                4.01          3.41         8.07              10.80
# 860                 4.35          2.22         6.57               8.89
#
#       exercise_minutes  caffeine_intake_mg  ...  mental_health_score  \
# 4227               132                 424  ...                    8
# 4676                67                 144  ...                    8
# 800                 10                 433  ...                    7
# 3671                31                 450  ...                    6
# 4193               124                 128  ...                    6
# ...                ...                 ...  ...                  ...
# 4426               122                  87  ...                    2
# 466                 34                 453  ...                   10
# 3092               142                 173  ...                    7
# 3772               135                 152  ...                    7
# 860                 43                 154  ...                    3
#
#       focus_index  burnout_level  productivity_score  gender_Male  \
# 4227        34.49          58.40               37.90        False
# 4676        45.53          34.64               60.30        False
# 800         35.48          53.50               61.49        False
# 3671        24.02          36.40               23.14         True
# 4193        36.39          40.93               42.99        False
# ...           ...            ...                 ...          ...
# 4426        36.18          40.42               31.42        False
# 466         38.26          57.39               45.30        False
# 3092        34.70          56.14               47.66        False
# 3772        21.78          48.07               43.06         True
# 860         16.28          36.62               21.36         True
#
#       gender_Other  academic_level_Postgraduate  academic_level_Undergraduate  \
# 4227         False                        False                         False
# 4676          True                        False                         False
# 800           True                        False                         False
# 3671         False                        False                         False
# 4193          True                        False                         False
# ...            ...                          ...                           ...
# 4426          True                         True                         False
# 466           True                        False                         False
# 3092          True                        False                         False
# 3772         False                         True                         False
# 860          False                         True                         False
#
#       internet_quality_Good  internet_quality_Poor
# 4227                  False                  False
# 4676                  False                  False
# 800                   False                   True
# 3671                   True                  False
# 4193                  False                   True
# ...                     ...                    ...
# 4426                  False                   True
# 466                   False                  False
# 3092                  False                   True
# 3772                  False                   True
# 860                   False                   True
#
# [4000 rows x 22 columns]

# %%
X_test
# Out:
#       age  study_hours  self_study_hours  online_classes_hours  \
# 1501   21         1.69              1.27                  2.03
# 2586   22         5.83              1.85                  1.52
# 2653   23         2.97              0.67                  2.80
# 1055   20         5.06              1.40                  2.57
# 705    19         4.36              2.25                  1.19
# ...   ...          ...               ...                   ...
# 4711   23         5.58              2.58                  1.56
# 2313   24         4.51              4.56                  4.21
# 3214   17         5.73              1.03                  2.08
# 2732   21         4.91              1.87                  2.53
# 1926   20         5.54              0.45                  3.25
#
#       social_media_hours  gaming_hours  sleep_hours  screen_time_hours  \
# 1501                3.01          0.93         7.76               9.30
# 2586                3.00          0.88         6.89              13.89
# 2653                1.72          0.75         5.00               7.78
# 1055                3.23          1.72         7.57               7.29
# 705                 0.24          1.89         6.49              10.59
# ...                  ...           ...          ...                ...
# 4711                4.78          3.46         8.01               9.64
# 2313                2.44          2.20         7.05              10.97
# 3214                2.79          0.86         8.15              10.37
# 2732                0.04          2.11         5.49               6.41
# 1926                1.19          0.89         7.19               3.08
#
#       exercise_minutes  caffeine_intake_mg  ...  mental_health_score  \
# 1501               141                   2  ...                   10
# 2586                41                  37  ...                    6
# 2653                10                 444  ...                    7
# 1055               146                 300  ...                   10
# 705                100                 185  ...                    6
# ...                ...                 ...  ...                  ...
# 4711                84                 237  ...                    7
# 2313                42                  16  ...                    5
# 3214                 9                 159  ...                    7
# 2732                 1                 207  ...                    9
# 1926               100                   1  ...                    4
#
#       focus_index  burnout_level  productivity_score  gender_Male  \
# 1501        33.02          34.29               49.20        False
# 2586        30.61          76.88               32.73        False
# 2653        34.04          60.70               34.98        False
# 1055        30.69          49.63               61.26         True
# 705         32.55          40.06               33.99        False
# ...           ...            ...                 ...          ...
# 4711        34.34          63.85               48.35         True
# 2313        34.82          49.19               38.50        False
# 3214        42.98          30.16               66.56        False
# 2732        44.49          52.79               54.11        False
# 1926        26.94          27.57               44.68        False
#
#       gender_Other  academic_level_Postgraduate  academic_level_Undergraduate  \
# 1501         False                         True                         False
# 2586          True                        False                         False
# 2653         False                        False                         False
# 1055         False                        False                         False
# 705          False                        False                          True
# ...            ...                          ...                           ...
# 4711         False                        False                          True
# 2313          True                        False                          True
# 3214          True                         True                         False
# 2732         False                        False                         False
# 1926         False                        False                          True
#
#       internet_quality_Good  internet_quality_Poor
# 1501                   True                  False
# 2586                  False                  False
# 2653                   True                  False
# 1055                   True                  False
# 705                   False                   True
# ...                     ...                    ...
# 4711                  False                   True
# 2313                   True                  False
# 3214                  False                   True
# 2732                   True                  False
# 1926                  False                  False
#
# [1000 rows x 22 columns]

# %%
y_test
# Out:
# 1501    1
# 2586    0
# 2653    0
# 1055    1
# 705     1
#        ..
# 4711    1
# 2313    1
# 3214    1
# 2732    1
# 1926    1
# Name: exam_performance, Length: 1000, dtype: int64

# %%
y_train
# Out:
# 4227    1
# 4676    1
# 800     1
# 3671    0
# 4193    1
#        ..
# 4426    0
# 466     1
# 3092    1
# 3772    0
# 860     0
# Name: exam_performance, Length: 4000, dtype: int64

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC()
svc.fit(X_train,y_train)
X_test.columns = X_test.columns.str.replace(' ', '')
y_pred=svc.predict(X_test)
print('Model accuracy score with default hyperparamenters:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with default hyperparamenters:{0:0.4f} 0.876

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print('confusion_matrix')
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# confusion_matrix
# [[446  63]
#  [ 61 430]]

# %%
print('accuracy_score')
print(accuracy_score(y_test,y_pred))
# Out:
# accuracy_score
# 0.876

# %%
from sklearn.metrics import classification_report
print('classification_report')
print(classification_report(y_test,y_pred))
# Out:
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       509
#            1       0.87      0.88      0.87       491
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.88      0.88      1000
# weighted avg       0.88      0.88      0.88      1000

# %%
svc=SVC(C=100.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=100.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=100.0:{0:0.4f} 0.875

# %%
svc=SVC(C=1200.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=1200.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=1200.0:{0:0.4f} 0.87

# %%
linear_kernel=SVC(kernel='linear',C=1.0)
linear_kernel.fit(X_train,y_train)
y_pred_test =linear_kernel.predict(X_test)

# %%
poly_svc=SVC(kernel='poly',C=1.0)
poly_svc.fit(X_train,y_train)
y_pred_test =poly_svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=1.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=1.0:{0:0.4f} 0.875

# %%
sigmoid_csv=SVC(kernel='sigmoid',C=100)
sigmoid_csv.fit(X_train,y_train)
y_pred =sigmoid_csv.predict(X_test)
print('Model accuracy score with rbf kernel and C=100.0,gamma=1.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=100.0,gamma=1.0:{0:0.4f} 0.538

# %%
sigmoid_csv=SVC(kernel='sigmoid',C=1000)
sigmoid_csv.fit(X_train,y_train)
y_pred =sigmoid_csv.predict(X_test)
print('Model accuracy score with rbf kernel and C=1000.0,gamma=1.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=1000.0,gamma=1.0:{0:0.4f} 0.538
