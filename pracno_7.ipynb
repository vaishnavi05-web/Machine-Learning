# %% [markdown]
# Aim: To apply support vector machine for classification and analyze the impact of different on model accuracy.
# Name: Vaishnavi Sandokar
# USN : CS24D007

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/ML /pulsar_stars.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %%
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %%
df.shape
# Out:
# (17898, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                17898 non-null  float64
#  1    Standard deviation of the integrated profile  17898 non-null  float64
#  2    Excess kurtosis of the integrated profile     17898 non-null  float64
#  3    Skewness of the integrated profile            17898 non-null  float64
#  4    Mean of the DM-SNR curve                      17898 non-null  float64
#  5    Standard deviation of the DM-SNR curve        17898 non-null  float64
#  6    Excess kurtosis of the DM-SNR curve           17898 non-null  float64
#  7    Skewness of the DM-SNR curve                  17898 non-null  float64
#  8   target_class                                   17898 non-null  int64
# dtypes: float64(8), int64(1)
# ...

# %%
df.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df.columns
# Out:
# Index(['Meanoftheintegratedprofile', 'Standarddeviationoftheintegratedprofile',
#        'Excesskurtosisoftheintegratedprofile',
#        'Skewnessoftheintegratedprofile', 'MeanoftheDM-SNRcurve',
#        'StandarddeviationoftheDM-SNRcurve', 'ExcesskurtosisoftheDM-SNRcurve',
#        'SkewnessoftheDM-SNRcurve', 'target_class'],
#       dtype='object')

# %%
df.columns=[' Mean ','Standard ','Excess','Skewness','Standard ','Excess','Skewness','target','dtype']

# %%
df.column=['Mean','Standard',]

# %%
df.columns
# Out:
# Index([' Mean ', 'Standard ', 'Excess', 'Skewness', 'Standard ', 'Excess',
#        'Skewness', 'target', 'dtype'],
#       dtype='object')

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ Mean , Standard , Excess, Skewness, Standard , Excess, Skewness, target, dtype]
# Index: []

# %%
df.shape
# Out:
# (17898, 9)

# %%
before_rows=df.shape[0]
df=df.dropna()
after_rows=df.shape[0]
print('before_rows:',before_rows)
print('after_rows:',after_rows)
print("the number of dropped rows are:", before_rows-after_rows)
# Out:
# before_rows: 17898
# after_rows: 17898
# the number of dropped rows are: 0

# %%
df.shape
# Out:
# (17898, 9)

# %%
X.head
# Out:
# <bound method NDFrame.head of        Mean of the integrated profile  \
# 0                          140.562500
# 1                          102.507812
# 2                          103.015625
# 3                          136.750000
# 4                           88.726562
# ...                               ...
# 17893                      136.429688
# 17894                      122.554688
# 17895                      119.335938
# 17896                      114.507812
# 17897                       57.062500
#
#        Standard deviation of the integrated profile  \
# 0                                         55.683782
# 1                                         58.882430
# 2                                         39.341649
# 3                                         57.178449
# 4                                         40.672225
# ...                                             ...
# 17893                                     59.847421
# ...

# %%
X_train.columns = X_train.columns.str.replace(' ', '')
cols = X_train.columns
print(cols)
# Out:
# Index(['Meanoftheintegratedprofile', 'Standarddeviationoftheintegratedprofile',
#        'Excesskurtosisoftheintegratedprofile',
#        'Skewnessoftheintegratedprofile', 'MeanoftheDM-SNRcurve',
#        'StandarddeviationoftheDM-SNRcurve', 'ExcesskurtosisoftheDM-SNRcurve',
#        'SkewnessoftheDM-SNRcurve'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)

# %%
X_train
# Out:
#        Mean of the integrated profile  \
# 12223                      121.156250
# 1919                        76.968750
# 2753                       130.585938
# 17220                      156.398438
# 12110                       84.804688
# ...                               ...
# 11284                      124.312500
# 11964                      115.617188
# 5390                       116.031250
# 860                        135.664062
# 15795                      120.726562
#
#        Standard deviation of the integrated profile  \
# 12223                                     48.372971
# 1919                                      36.175557
# 2753                                      53.229534
# 17220                                     48.865942
# 12110                                     36.117659
# ...                                             ...
# 11284                                     53.179053
# 11964                                     46.784600
# ...

# %%
X_test
# Out:
#        Mean of the integrated profile  \
# 15985                      116.906250
# 8188                        75.585938
# 8157                       103.273438
# 2589                       101.078125
# 11909                      113.226562
# ...                               ...
# 12653                      116.531250
# 6454                       114.976562
# 530                        136.171875
# 1540                       106.500000
# 6921                       110.679688
#
#        Standard deviation of the integrated profile  \
# 15985                                     48.920605
# 8188                                      34.386254
# 8157                                      46.996628
# 2589                                      48.587487
# 11909                                     48.608804
# ...                                             ...
# 12653                                     51.140269
# 6454                                      53.783052
# ...

# %%
y_test
# Out:
# 15985    0
# 8188     1
# 8157     0
# 2589     1
# 11909    0
#         ..
# 12653    0
# 6454     0
# 530      0
# 1540     0
# 6921     1
# Name: target_class, Length: 5370, dtype: int64

# %%
y_train
# Out:
# 12223    0
# 1919     0
# 2753     0
# 17220    0
# 12110    0
#         ..
# 11284    0
# 11964    0
# 5390     0
# 860      0
# 15795    0
# Name: target_class, Length: 12528, dtype: int64

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC()
svc.fit(X_train,y_train)
X_test.columns = X_test.columns.str.replace(' ', '')
y_pred=svc.predict(X_test)
print('Model accuracy score with default hyperparamenters:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with default hyperparamenters:{0:0.4f} 0.9728119180633147

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print('confusion_matrix')
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# confusion_matrix
# [[4861   23]
#  [ 123  363]]

# %%
print('accuracy_score')
print(accuracy_score(y_test,y_pred))
# Out:
# accuracy_score
# 0.9728119180633147

# %%
from sklearn.metrics import classification_report
print('classification_report')
print(classification_report(y_test,y_pred))
# Out:
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4884
#            1       0.94      0.75      0.83       486
#
#     accuracy                           0.97      5370
#    macro avg       0.96      0.87      0.91      5370
# weighted avg       0.97      0.97      0.97      5370

# %%
svc=SVC(C=100.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=100.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=100.0:{0:0.4f} 0.9780260707635009

# %%
svc=SVC(C=1200.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=1200.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=1200.0:{0:0.4f} 0.9793296089385475

# %%
linear_kernel=SVC(kernel='linear',C=1.0)
linear_kernel.fit(X_train,y_train)
y_pred_test =linear_kernel.predict(X_test)

# %%
poly_svc=SVC(kernel='poly',C=1.0)
poly_svc.fit(X_train,y_train)
y_pred_test =poly_svc.predict(X_test)
print('Model accuracy score with rbf kernel and C=1.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=1.0:{0:0.4f} 0.9793296089385475

# %%
sigmoid_csv=SVC(kernel='sigmoid',C=100)
sigmoid_csv.fit(X_train,y_train)
y_pred =sigmoid_csv.predict(X_test)
print('Model accuracy score with rbf kernel and C=100.0,gamma=1.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=100.0,gamma=1.0:{0:0.4f} 0.9208566108007449

# %%
sigmoid_csv=SVC(kernel='sigmoid',C=1000)
sigmoid_csv.fit(X_train,y_train)
y_pred =sigmoid_csv.predict(X_test)
print('Model accuracy score with rbf kernel and C=1000.0,gamma=1.0:{0:0.4f}',format(accuracy_score(y_test,y_pred)))
# Out:
# Model accuracy score with rbf kernel and C=1000.0,gamma=1.0:{0:0.4f} 0.9208566108007449
